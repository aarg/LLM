# %% [markdown]
# Installing Lamini for interacting with the model

# %%
pip install lamini

# %%
from llama import BasicModelRunner

# %% [markdown]
# Interact with Base (non-finetuned) model

# %%
non_finetuned = BasicModelRunner("meta-llama/Llama-2-7b-hf")

# %%
from llama import LLMEngine

# %% [markdown]
# Login [here](https://app.lamini.ai/account) to generate key, copy the key from Accounts section
# Read more [here](https://lamini-ai.github.io/#installation)

# %%
llm = LLMEngine(
    id="example_llm",
    config={"production.key": "XXX"}
    )

# %% [markdown]
# # Interact with base model

# %%
non_finetuned_output = non_finetuned("Tell me how to train my dog to sit")

# %%
print(non_finetuned_output)
# Out:
# .
# Tell me how to train my dog to stay.
# Tell me how to teach my dog to come.
# Tell me how to get my dog to heel.
# Tell me how to stop my dog from barking.
# Tell me how to house train my dog.
# Tell me how to potty train my dog.
# Tell my how to train my dog to walk on a leash.
# Tell me how to crate train my dog.
# Tell Me How To Train My Dog To Sit, Stay, Come, Heel, Stop Barking, House Train, Potty Train, Walk On A Leash, Crate Train, And More!
# Tell Me How To Train Your Dog To Sit, Stay, Heel, Come, Walk On A Leash, House Train, Potty Train And More!
# Tell Me how to train my dog to sit, stay, come, heel, stop barking, house train, potty train, walk on a leash, crate train, and more!
# Tell Me How To House Train My Dog!
# Tell Me How To Potty Train My Dog!
# Tell me how to

# %%
non_finetuned_output = non_finetuned("What is finetuning?")

# %%
print(non_finetuned_output)
# Out:
# What is the difference between finetuning and retraining?
# What is the difference between retraining and finetuning?
# What is finetuning in machine learning?
# What is finetuning and how does it work?
# What is the difference between training and finetuning?
# What does finetuning mean?
# What is the difference between fine tuning and retraining?
# What is finetuning a model?
# What is the difference between tuning and finetuning?
# What are the benefits of finetuning?
# What is fine tuning in machine learning?
# What is the difference between retuning and retraining?
# What does finetuning a model mean?
# What is the difference in training and finetuning?
# How do you finetune a model?
# What is the purpose of finetuning?
# What does it mean to finetune a model?
# How do you finetuning a model?
# How do you fine tune a model?
# What is finetuning?
# What does fine tuning mean?
# What is the difference of retraining and finetuning?

# %% [markdown]
# # Interact with finetuned model

# %%
finetuned_model = BasicModelRunner("meta-llama/Llama-2-7b-chat-hf")

# %%
finetuned_output = finetuned_model("What is finetuning?")

# %%
print(finetuned_output)
# Out:
# Finetuning is a process in machine learning where a pre-trained model is adjusted for a specific task or dataset. The goal of finetuning is to improve the performance of the model on the new task or dataset by adapting the model's weights to the new data.
# Finetuning is different from training a model from scratch, where the entire model is trained on the new dataset. Finetuning is faster and more efficient than training a model from scratch, as the pre-trained model has already learned general features that can be applied to the new task.
# Finetuning can be applied to various machine learning models, including deep learning models like transformers and convolutional neural networks (CNNs). It is commonly used in natural language processing (NLP) and computer vision tasks, where pre-trained models are widely available and can be fine-tuned for specific tasks like language translation, sentiment analysis, and image classification.
# ...
